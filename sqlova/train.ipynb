# %%
# !git clone https://github.com/fastai/courses.git

# %%
from google.colab import drive
# drive.mount('/content/gdrive')

# !cp -r gdrive/My\ Drive/text2sql/sqlova/*.py .
# !cp -r gdrive/My\ Drive/text2sql/sqlova/sqlnet/ .   
#!pip3 install records

# !python3 train.py --seed 1 --bS 16 --accumulate_gradients 2 --bert_type_abb uL --fine_tune --lr 0.001 --lr_bert 0.00001 --max_seq_leng 222 --EG
# Out:
# BERT-type: uncased_L-24_H-1024_A-16
# Batch_size = 32
# BERT parameters:
# learning rate: 1e-05
# Fine-tune BERT: True
# vocab size: 30522
# hidden_size: 1024
# num_hidden_layer: 24
# num_attention_heads: 16
# hidden_act: gelu
# intermediate_size: 4096
# hidden_dropout_prob: 0.1
# attention_probs_dropout_prob: 0.1
# max_position_embeddings: 512
# type_vocab_size: 2
# initializer_range: 0.02
# Load pre-trained parameters.
# Seq-to-SQL: the number of final BERT layers to be used: 2
# Seq-to-SQL: the size of hidden dimension = 100
# Seq-to-SQL: LSTM encoding layer size = 2
# Seq-to-SQL: dropout rate = 0.3
# Seq-to-SQL: learning rate = 0.001
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1332: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# dev results ------------
# ...

# %%
# !ls -al
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Mar 12 10:38 .
# drwxr-xr-x 1 root root 4096 Mar 12 10:37 ..
# drwxr-xr-x 4 root root 4096 Mar  8 17:25 .config
